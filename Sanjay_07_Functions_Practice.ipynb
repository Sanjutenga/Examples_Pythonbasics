# %%
# calculate length of the program by using function without using inbuilt function called len()
l = "sanju",89,68
def test(l):
  count = 0
  for i in l:
   # if type(i) == str:
      count = count+1
  return count

# %%
l = "sanju",6,7,5
test(l)
# Out:
# 4

# %%
l = 6,79.9,5,4,5,4,5,3,True, 3+4j, 48
test(l)
# Out:
# 11

# %%
test("Rajathaa")
# Out:
# 8

# %%
# calculate index of an element in an list without using the inbuilt function called index in an program by using functions
def test(l):
  for i in range(0,len(l)):
    if type(i) == int:
      print(l[i],":",i)

# %%
test([4,5,3,5,3,5,8])
# Out:
# 4 : 0
# 5 : 1
# 3 : 2
# 5 : 3
# 3 : 4
# 5 : 5
# 8 : 6

# %%
a = [7494,5,3,5,3]
test(a)
# Out:
# 7494 : 0
# 5 : 1
# 3 : 2
# 5 : 3
# 3 : 4

# %%
def tee(l):
  for i in range(0,len(l)):
    if type(i) == int:
      print(i,":",l[i])

# %%
tee([8,4,3,4,3,45,3,54,3])
# Out:
# 0 : 8
# 1 : 4
# 2 : 3
# 3 : 4
# 4 : 3
# 5 : 45
# 6 : 3
# 7 : 54
# 8 : 3

# %%
def test(l):      #By using Enumerate we can find index of an element
  for i in enumerate(l):
    print(i)

# %%
test([5,5,2,45,2,45,2,54])
# Out:
# (0, 5)
# (1, 5)
# (2, 2)
# (3, 45)
# (4, 2)
# (5, 45)
# (6, 2)
# (7, 54)

# %%
def test(l):
  for i in range(0,len(l)):
    print(l[i],":",i)

# %%
test([5,5,3,5,3,5,3,5,])
# Out:
# 5 : 0
# 5 : 1
# 3 : 2
# 5 : 3
# 3 : 4
# 5 : 5
# 3 : 6
# 5 : 7

# %%
#33...Print an IP address of your system by using functions
import socket
def test():
 ip = socket.gethostbyname(socket.gethostname())
 return ip
# Out:
# '172.28.0.2'

# %%
## 44. Write the program of function to shutdown of your system
## /s -- shut down
## /r -- restart
## /t 4 -- timer
import os
os.system("shutdown /r /t 2")
# Out:
# 256

# %%
import os
os.sysytem('restart /r /t 8')

# %%
#555. numeric value multiplication
l = [3.5,6.56,4,5,"sanju","ineuron","fsda bootcamp 2.0"]
# addition of whole list a = 0, a = a +i

def test(l):
  mul = 1
  for i in l:
    if type(i) == float or type(i) == int:
      mul = mul * i
  return mul

# %%
test(l)
# Out:
# 459.19999999999993

# %%
a = [4,5]
test(a)
# Out:
# 20

# %%
b = (4,5,6)
test(b)
# Out:
# 120

# %%
test({4,5,6})
# Out:
# 120

# %%
def tee(l):
  mul = 1
  for i in l:
    if type(i) == int or type(i) == float:
      mul = mul * i
  return mul

# %%
tee([4,5.0])
# Out:
# 20.0

# %%
def test(l):
  mul = 1
  for i in l:
    if type(i) == int or type(i) == float:
      mul = mul * i
  return mul

# %%
test({4,5.6})
# Out:
# 22.4

# %%
# 66 . Write the function to read all the mails
# Python 3.8.0
import smtplib
import time
import imaplib
import email
import traceback 
# -------------------------------------------------
#
# Utility to read email from Gmail Using Python
#
# ------------------------------------------------
ORG_EMAIL = "@gmail.com" 
FROM_EMAIL = "sanjugowdru3518@gmail.com"
FROM_PWD = "gxwrlgkmntpjvrzt" 
SMTP_SERVER = "imap.gmail.com" 
SMTP_PORT = 993
imaplib._MAXLINE = 400000000

def read_email_from_gmail():
    try:
        mail = imaplib.IMAP4_SSL(SMTP_SERVER)
        mail.login(FROM_EMAIL,FROM_PWD)
        mail.select('inbox')

        data = mail.search(None, 'ALL')
        mail_ids = data[1]
        id_list = mail_ids[0].split()   
        first_email_id = int(id_list[0])
        latest_email_id = int(id_list[-1])

        for i in range(latest_email_id,first_email_id, -1):
            data = mail.fetch(str(i), '(RFC822)' )
            for response_part in data:
                arr = response_part[0]
                if isinstance(arr, tuple):
                    msg = email.message_from_string(str(arr[1],'utf-8'))
                    email_subject = msg['subject']
                    email_from = msg['from']
                    print('From : ' + email_from + '\n')
                    print('Subject : ' + email_subject + '\n')

    except Exception as e:
        traceback.print_exc() 
        print(str(e))

read_email_from_gmail()
# Out:
# From : Monster Jobs <jobmessenger@monsterindia.com>
#
# Subject : Trustegic Solution and others are hiring. Apply now!
#
# From : "Adobe Acrobat" <demand@mail.adobe.com>
#
# Subject : =?utf-8?B?T3BlbiwgZmlsbCwgc2lnbiwgYW5kIHNlbmQ=?=
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Someone added you as their recovery email
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert for sanjaylang2@gmail.com
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Your Google Account was recovered successfully
#
# From : Twitter <info@twitter.com>
#
# Subject : Bloomberg and 1 other shared "Bloomberg Growth Summit"
#
# From : "Grammarly Insights" <info@send.grammarly.com>
#
# Subject : New badges & a new record! You did great last week!
#
# From : =?UTF-8?B?R3Jvd3cgRGlnZXN0?= <noreply@digest.groww.in>
#
# ...

# %%
# 77.  Write the function to send the mail to anyone
import smtplib, ssl
port = 465  # For starttls
smtp_server = "smtp.gmail.com"
sender_email = "sanjugowdru3518@gmail.com"  # sender mail
receiver_email = "sanjaydjango33@gmail.com"  # receiver mail
password = 'gxwrlgkmntpjvrzt'
message = """\
Subject: Hi there

This message is sent from Python."""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)

# %%
#8.. Write a function which will be able to read doc/word file in your system
import docx2txt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-175ed20ac9f4> in <module>
#       1 #10.. Write a function which will be able to read doc/word file in your system
# ----> 2 import docx2txt
#
# ModuleNotFoundError: No module named 'docx2txt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install docx2txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=3896219028a443fd51f83df92038dca41b4b196b55c399b4243c67e8c9a7b279
#   Stored in directory: /root/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# Successfully built docx2txt
# ...

# %%
import docx2txt
a = docx2txt.process("test.docx")
print(a)
# Out:
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# gxwrlgkmntpjvrzt
#
# ...
